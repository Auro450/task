# %%
import pandas as pd
import numpy as np

# %%
superstore_df = pd.read_excel("Superstore_USA.xlsx")

# %%
superstore_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
superstore_df1 = pd.read_excel("Superstore_USA.xlsx", sheet_name="Returns") #Find out how return that we ahve recived and with a product id

# %%
superstore_df1
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
superstore_merged_df = pd.merge(superstore_df,superstore_df1, on="Order ID",) #try  to join order and return data both in sql and pandas

# %%
superstore_merged_df
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
superstore_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 0 to 97
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                98 non-null     int64
#  1   Order Priority        98 non-null     object
#  2   Discount              98 non-null     float64
#  3   Unit Price            98 non-null     float64
#  4   Shipping Cost         98 non-null     float64
#  5   Customer ID           98 non-null     int64
#  6   Customer Name         98 non-null     object
#  7   Ship Mode             98 non-null     object
#  8   Customer Segment      98 non-null     object
#  9   Product Category      98 non-null     object
#  10  Product Sub-Category  98 non-null     object
#  11  Product Container     98 non-null     object
#  12  Product Name          98 non-null     object
#  13  Product Base Margin   96 non-null     float64
#  14  Region                98 non-null     object
# ...

# %%
superstore_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
superstore_df["Customer ID"].nunique() #Try to find out how many unique customer that we have
# Out:
# 2703

# %%
superstore_df["Region"].unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
superstore_df2 = pd.read_excel("Superstore_USA.xlsx",sheet_name="Users") #try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
superstore_df2
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
superstore_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
superstore_df["Ship Mode"].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
shipment_df = pd.DataFrame(superstore_df["Ship Mode"].value_counts()) #find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
shipment_df
# Out:
#                 Ship Mode
# Regular Air          7036
# Delivery Truck       1283
# Express Air          1107

# %%
shipment_df["shipment_percentage"] = (shipment_df["Ship Mode"]/shipment_df["Ship Mode"].sum())*100 #find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
shipment_df
# Out:
#                 Ship Mode  shipment_percentage
# Regular Air          7036            74.644600
# Delivery Truck       1283            13.611288
# Express Air          1107            11.744112

# %%
superstore_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
superstore_df["order_day"] = superstore_df["Order Date"].dt.day

# %%
superstore_df["ship_day"] = superstore_df["Ship Date"].dt.day

# %%
superstore_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
superstore_df["day_difference"] = superstore_df["ship_day"] - superstore_df["order_day"]

# %%
superstore_df # Create a new coulmn and try to find our a diffrence between order date and shipment date
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
superstore_df[superstore_df["day_difference"]>10] #base on question number 8 find out for which order id we have shipment duration more than 10 days
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, order_day, ship_day, day_difference]
# Index: []
#
# [0 rows x 27 columns]

# %%
superstore_merged_df = pd.merge(superstore_df,superstore_df1, on="Order ID")

# %%
superstore_merged_df.head(60)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# 5     5574            Low      0.03      159.31          60.00          272
# 6     5302           High      0.01        8.33           1.99          308
# 7     5303           High      0.04       85.99           0.99          308
# 8     5257            Low      0.09      550.98          64.59          349
# 9     6643       Critical      0.02        5.98           5.46          349
# 10     979         Medium      0.01      280.98          57.00          478
# ...

# %%
no data as such found because shipment duration are not more than 9 days #Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
superstore_df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
superstore_df_region = superstore_df.groupby("Region")["Profit"].sum()

# %%
superstore_df_region.sort_values(ascending=False) # Gorup by region and find out which region is more profitable
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# West       310849.453897
# South      104201.192420
# Name: Profit, dtype: float64

# %%
superstore_df_country = superstore_df.groupby("State or Province")["Discount"].sum()

# %%
superstore_df_country.sort_values(ascending=False) #Try to find out overalll in which country we are giving more didscount
# Out:
# State or Province
# California              52.28
# Texas                   31.36
# Illinois                29.71
# New York                28.86
# Florida                 26.38
# Ohio                    19.71
# Washington              15.48
# Michigan                15.29
# Pennsylvania            13.32
# Minnesota               12.52
# Indiana                 12.22
# North Carolina          12.02
# Massachusetts           11.22
# Virginia                 9.80
# Georgia                  9.79
# Maryland                 8.85
# New Jersey               8.73
# Tennessee                8.55
# Oregon                   8.42
# Missouri                 8.09
# Wisconsin                8.06
# Colorado                 8.05
# Utah                     7.67
# Iowa                     7.15
# Kansas                   6.89
# Arizona                  6.86
# Maine                    6.66
# Alabama                  5.87
# Arkansas                 5.80
# Idaho                    5.57
# ...

# %%
superstore_df["Postal Code"].unique() # Give me a list of unique postal code
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
superstore_df_customer_segment = superstore_df.groupby("Customer Segment")["Profit"].sum()

# %%
superstore_df_customer_segment.sort_values(ascending=False) #which customer segement is more profitalble find it out
# Out:
# Customer Segment
# Corporate         505538.627783
# Small Business    316474.592482
# Home Office       283869.553814
# Consumer          206559.625348
# Name: Profit, dtype: float64

# %%
superstore_df_prod_cat = superstore_df.groupby("Product Category")["Profit"].sum()

# %%
superstore_df_prod_cat # try to find out the 10th most loss making product catagory . not in range only 3 prod cat
# Out:
# Product Category
# Furniture          177354.298188
# Office Supplies    451990.216492
# Technology         683097.884748
# Name: Profit, dtype: float64

# %%
superstore_df["Product Category"].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
superstore_df_prod_sb_cat = superstore_df.groupby("Product Sub-Category")["Profit"].sum()

# %%
superstore_df_prod_sb_cat.sort_values(ascending=True)[9] #try to find out the 10th most loss making product catagory = Computer Peripherals               87917.842513
# Out:
# 87917.8425126

# %%
superstore_df_prod_sb_cat.sort_values(ascending=True)
# Out:
# Product Sub-Category
# Tables                            -72495.061875
# Bookcases                          -7708.748564
# Rubber Bands                       -2841.722459
# Scissors, Rulers and Trimmers      -1936.849120
# Pens & Art Supplies                 1195.902840
# Storage & Organization              8078.804727
# Labels                             17775.320505
# Paper                              35361.621738
# Envelopes                          46133.223840
# Computer Peripherals               87917.842513
# Office Furnishings                 92209.225867
# Appliances                        121651.391380
# Copiers and Fax                   129156.684030
# Chairs & Chairmats                165348.882760
# Office Machines                   168072.833340
# Binders and Binder Accessories    226572.523042
# Telephones and Communication      297950.524866
# Name: Profit, dtype: float64

# %%
superstore_df_prod_sb_cat.sort_values(ascending=False).nlargest(10) #Try to find out 10 top  product with highest margins
# Out:
# Product Sub-Category
# Telephones and Communication      297950.524866
# Binders and Binder Accessories    226572.523042
# Office Machines                   168072.833340
# Chairs & Chairmats                165348.882760
# Copiers and Fax                   129156.684030
# Appliances                        121651.391380
# Office Furnishings                 92209.225867
# Computer Peripherals               87917.842513
# Envelopes                          46133.223840
# Paper                              35361.621738
# Name: Profit, dtype: float64

# %%
sir, sql and mongodb portion is not done yet i have to revise that portion as i forgot some of the queries 
and with mongodb i have some problem as everytime while connecting with atlas it is generating system timeout error i dont know why
