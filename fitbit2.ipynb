# %%
import pandas as pd 
import numpy as np

# %%
df_fitbit = pd.read_csv("FitBit data.csv")

# %%
df_fitbit.head(5)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df_fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %%
df_fitbit['ActivityDate'] = pd.to_datetime(df_fitbit['ActivityDate'])

# %%
df_fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    datetime64[ns]
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %%
df_fitbit["Id"].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
df_fitbit["Id"].nunique()
# Out:
# 35

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_fitbit["Active_minutes"] = df_fitbit["VeryActiveMinutes"]+df_fitbit["FairlyActiveMinutes"]+df_fitbit["LightlyActiveMinutes"]

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_fitbit_grouped = df_fitbit.groupby("Id")["Active_minutes"].sum()

# %%
df_fitbit_grouped.sort_values(ascending = False)
# Out:
# Id
# 1503960366    5318
# 4020332650    4547
# 6962181067    4521
# 2347167796    4327
# 7007744171    4061
# 4702921684    4004
# 8877689391    3875
# 2022484408    3797
# 2873212765    3436
# 4319703577    3282
# 4445114986    3099
# 4558609924    3083
# 6117666160    3045
# 3372868164    3022
# 3977333714    3004
# 5577150313    2940
# 1644430081    2860
# 8378563200    2816
# 8053475328    2756
# 5553957443    2683
# 1624580081    2325
# 2026352035    2032
# 2891001357    2010
# 1844505072    1920
# 7086361926    1742
# 6775888955    1738
# 8792009665    1668
# 4057192912    1593
# 2320127002    1535
# 1927972279    1360
# 8583815059    1117
# 8253242879     837
# 6290855005     578
# 6391747486     361
# 4388161847       0
# Name: Active_minutes, dtype: int64

# %%
1503960366 is the most active id
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_4820/2474161291.py", line 1
#     1503960366 is the most active id
#                       ^
# SyntaxError: invalid syntax

# %%
df1 =df_fitbit[df_fitbit["LoggedActivitiesDistance"] == 0]
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df1["Id"].nunique() #no od ids not logged in
# Out:
# 35

# %%
df_fitbit_grouped.sort_values(ascending = True)
# Out:
# Id
# 4388161847       0
# 6391747486     361
# 6290855005     578
# 8253242879     837
# 8583815059    1117
# 1927972279    1360
# 2320127002    1535
# 4057192912    1593
# 8792009665    1668
# 6775888955    1738
# 7086361926    1742
# 1844505072    1920
# 2891001357    2010
# 2026352035    2032
# 1624580081    2325
# 5553957443    2683
# 8053475328    2756
# 8378563200    2816
# 1644430081    2860
# 5577150313    2940
# 3977333714    3004
# 3372868164    3022
# 6117666160    3045
# 4558609924    3083
# 4445114986    3099
# 4319703577    3282
# 2873212765    3436
# 2022484408    3797
# 8877689391    3875
# 4702921684    4004
# 7007744171    4061
# 2347167796    4327
# 6962181067    4521
# 4020332650    4547
# 1503960366    5318
# Name: Active_minutes, dtype: int64

# %%
id with 4388161847 is the laziest person

# %%
df2 = df_fitbit[(df_fitbit["Calories"] >= 500) | (df_fitbit["Calories"] <= 1000)]
df2
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df2["Id"].nunique()
# Out:
# 35

# %%
df_fitbit_groupedbyid = df_fitbit.groupby("Id")

# %%
df_fitbit_groupedbyid_activedistance = df_fitbit_groupedbyid["LoggedActivitiesDistance"].sum()

# %%
df3 = pd.DataFrame(df_fitbit_groupedbyid_activedistance)
df3 = df3[df3["LoggedActivitiesDistance"]==0]
df3.value_counts() #29 ids not logged
# Out:
# LoggedActivitiesDistance
# 0.0                         29
# dtype: int64

# %%
df_fitbit_groupedbyid = df_fitbit.groupby("Id")
df_fitbit_groupedbyid_calories = df_fitbit_groupedbyid["Calories"].sum()/30
df4 = pd.DataFrame(df_fitbit_groupedbyid_calories)
df4 = df4[df4["Calories"]>=500]
df4.count()
# Out:
# Calories    34
# dtype: int64

# %%
34 ids are healthy person who are burning more than 500 cal per day

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4820/2540878783.py in <module>
# ----> 1 fitbit_df
#
# NameError: name 'fitbit_df' is not defined

# %%
df_fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_fitbit_groupedbyid = df_fitbit.groupby("Id")

# %%
df_fitbit_groupedid_activeminsum = df_fitbit_groupedbyid["Active_minutes"].sum().nlargest(3)
df_fitbit_groupedid_activeminsum
# Out:
# Id
# 1503960366    5318
# 4020332650    4547
# 6962181067    4521
# Name: Active_minutes, dtype: int64

# %%
6962181067 is the 3rd most active person

# %%
df_fitbit_groupedid_activeminsum = df_fitbit_groupedbyid["Active_minutes"].sum()
s = df_fitbit_groupedid_activeminsum.sort_values(ascending = True)
df5 = s.to_frame()
df5
# Out:
#             Active_minutes
# Id
# 4388161847               0
# 6391747486             361
# 6290855005             578
# 8253242879             837
# 8583815059            1117
# 1927972279            1360
# 2320127002            1535
# 4057192912            1593
# 8792009665            1668
# 6775888955            1738
# 7086361926            1742
# 1844505072            1920
# 2891001357            2010
# 2026352035            2032
# 1624580081            2325
# 5553957443            2683
# 8053475328            2756
# 8378563200            2816
# 1644430081            2860
# 5577150313            2940
# 3977333714            3004
# 3372868164            3022
# 6117666160            3045
# 4558609924            3083
# 4445114986            3099
# 4319703577            3282
# 2873212765            3436
# 2022484408            3797
# 8877689391            3875
# 4702921684            4004
# 7007744171            4061
# 2347167796            4327
# 6962181067            4521
# ...

# %%
8583815059 is the 5 laziest

# %%
df_fitbit_groupedbyid = df_fitbit.groupby("Id")
df_fitbit_groupedbyid_calories = df_fitbit_groupedbyid["Calories"].sum()
df_fitbit_groupedbyid_calories
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64
